# %%
import pandas as pd

# Load the CSV data into a DataFrame
csv_file_path = 'programming_languages_2004_2023.csv'
data = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
data.head()
# Out:
#              Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0       July 2004  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1     August 2004  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2  September 2004  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3    October 2004  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4   November 2004  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 0    0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 1    0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2    0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 3    0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 4    0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
#    TypeScript   VBA  Visual Basic
# 0         0.0  1.43          8.50
# 1         0.0  1.45          8.51
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'Date' to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Set the Date as index
data.set_index('Date', inplace=True)

# Selecting a subset of programming languages for a clearer line plot
selected_languages = ['Java', 'Python', 'C#', 'JavaScript']

# Start a figure
plt.figure(figsize=(20, 15))

# Line plot for selected programming languages
plt.subplot(2, 2, 1)
for language in selected_languages:
    plt.plot(data.index, data[language], label=language)
plt.title('Trend of Selected Programming Languages Over Time')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.legend()

# Bar plot for the languages in the latest month in the data
plt.subplot(2, 2, 2)
latest_month_data = data.iloc[-1]  # get the latest month
sns.barplot(x=latest_month_data.index, y=latest_month_data.values)
plt.title('Popularity of Programming Languages in January 2005')
plt.xlabel('Programming Language')
plt.ylabel('Popularity')
plt.xticks(rotation=90)  # rotate the x labels to show them clearly

# Heatmap for all the programming languages
plt.subplot(2, 2, 3)
sns.heatmap(data.T, cmap='YlGnBu')
plt.title('Heatmap of Programming Languages Popularity Over Time')
plt.xlabel('Date')
plt.ylabel('Programming Language')

# Box plot for all programming languages
plt.subplot(2, 2, 4)
sns.boxplot(data=data, orient='h')
plt.title('Distribution of Programming Languages Popularity')
plt.xlabel('Popularity')
plt.ylabel('Programming Language')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /var/folders/cn/zl1xy7rd5f565s43xr337bfm0000gn/T/ipykernel_15052/2077407796.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])
